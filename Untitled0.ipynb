# %%
#03-08
subcribed = True
subcription_status = 'active'
subscription_type = 'bronze' # bronze, silver, gold

bronze_allowed_bookings = ['therapist', 'heart specialist']
silver_allowed_bookings = ['therapist', 'heart specialist', 'fitness coach']
gold_allowed_bookings = ['therapist', 'heart specialist', 'fitness coach', 'child specialist']


booking_specialist = input('With which specialist do you want to have an appointment? ')
if subcribed == True:
  print("your are subcribed.")
  if subcription_status == 'active':
    print('your subcription status is active.')
    if subscription_type == 'bronze':
      print("Your subscription_type is Bronze.")
      if booking_specialist in bronze_allowed_bookings:
        print("Your booking_specialist is not in you.")
      else:
        print('please try again.')
    else:
      print('your subscription type is invalid.')
  else:
    print('your subcription status is not active.')



# Booking confirmed Message: 'Your booking confirmed with {professional}
# Error Message: 'Please subscribe first to book an appointment' (Example)
